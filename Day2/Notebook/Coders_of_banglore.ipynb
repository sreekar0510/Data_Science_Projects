# %%
# Parsing Data in Pure Python

# %%
# Raw Data → Clean Data → Structured Data → Insights  (THIS IS OUR MAIN GOAL;)

# %%
with open("initialdata.txt",encoding='utf-8') as f:  # utf-8 modern standard language to deal all the symbols and data
    data=f.read()

# %%
data
# Out:
# "intaglobal\n1,946 posts\n6,851 followers\n262 following\nINTA\nNonprofit organization\nThe association of ™ professionals.\ninta.campsite.bio\n\n_anujsinghal\n1,785 posts\n681K followers\n248 following\nAnuj Singhal\nDigital creator\nManaging Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul\n\ncode_flare\n165 posts\n216 followers\n10 following\nThe Journey Notebook | Travel | Food Blogger\nBlogger\n📍 Exploring places & phases of life 🌍\n.\n🍵 From chai breaks to flight takes ✈️\n.\n💫 Travel | Food | Daily life 🌸\nyoutube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a\n\nbangalore_tech_bro\n402 posts\n12.5K followers\n890 following\nRahul | HSR Hustler\nEntrepreneur\n🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds\n\nsilkboard_survivor\n55 posts\n1,200 followers\n50 following\nPriya D.\nPublic Figure\n🚦 Stuck in traffic since 2019\n🌧️ Loving the Bangalore weather, hating the cabs\n🐍 Data Scientist by day, meme maker by night\n📍 ORR\nbit.ly/my-traffic-rants\n\nstartuphub_blr\n2,300 posts\n45K followers\n120 following\nStartup Hub Bangalore\nMedia\n🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter\n\nfoodie_in_kora\n890 posts\n5,600 followers\n400 following\nSneha | Bangalore Eats\nFood & Drink\nAagrah to Truffles 🍔\nExploring Koramangala's cafe culture ☕\nDM for collabs\nhttps://www.google.com/search?q=zomato.com/users/sneha123\n\nventure_vikram\n120 posts\n30K followers\n500 following\nVikram | Angel Investor\nInvestor\n💸 Helping founders go 0 to 1\nEx-Google, Ex-Amazon\nInvesting in DeepTech & AI\n📍 Indiranagar\nvikram.vc/pitch-deck\n\npython_meetup_blr\n60 posts\n3,400 followers\n10 following\nPyBangalore Community\nCommunity\n🐍 Weekly meetups for Pythonistas\n📍 Cubbon Park | Sundays 4 PM\nCoding + Coffee + Community\nhttps://www.google.com/search?q=meetup.com/pybangalore\n\nindiranagar_gossip\n300 posts\n8,900 followers\n20 following\nIndiranagar Spy\nPersonal Blog\nNot just about 100ft Road 🤫\nSpilling tea on the best brunches and worst landlords\nBengaluru\nhttps://www.google.com/search?q=medium.com/%40indiranagarspy\n\n\nig_arbin07\n50 posts\n33 followers\n30 following\naarbinnn\nGamer\n@dumb.arbin\n🎮: Banana『juice (IGL🥷)\nGamer never die, they just respawn🙂\u200d↔️\n\n\n\n7iiuliiu\n1 post\n44 followers\n166 following\n︎𝐄︎ ♡︎.\n\n\nkatiasales2220\n107 posts\n219 followers\n1,401 following\nKatia Sales\nAlfabetização e Reforço Escolar\nEnsino Fundamental I e II\nPreparação para Escola Militar\nPortuguês e Matemática\nCursando Psicopedagogia Estácio"

# %%
chunks = data.split('\n\n')
chunks = [c for c in chunks if len(c)>3]  #removes the empty chunks like "  " and "\n\n\n"
chunks[10]
# Out:
# '\nig_arbin07\n50 posts\n33 followers\n30 following\naarbinnn\nGamer\n@dumb.arbin\n🎮: Banana『juice (IGL🥷)\nGamer never die, they just respawn🙂\u200d↔️'

# %%
# The goal is to convert each chunk from raw text into a clean Python dictionary.
# For that, we define a function that trims extra whitespace, separates the lines, removes labels, and returns the meaningful parts.

def parse_chunk(chunk):
    chunk=chunk.strip() #removes spaces 
    lines = chunk.split("\n")
    username = lines[0]
    posts = int(lines[1].split(" post")[0].replace(",", "")) #counting posts numbers by converting no into int
    #counting followers numbers by converting K and M no's into int
    followers = float(lines[2].split(" followers")[0].replace(",","").replace("K","").replace("M",""))
    if "K" in lines[2]:
        followers=int(followers*1000)
    elif "M" in lines[2]:
        followers= int(followers*1000000)
    else:
        followers=int(followers)
        
    #counting following numbers by converting K and M no's into int
    following= float(lines[3].split(" following")[0].replace(",","").replace("K","").replace("M",""))
    if "K" in lines[2]:
        following=int(following*1000)
    elif "M" in lines[2]:
        following= int(following*1000000)
    else:
        following=int(following)

    # 
    name = lines[4] if len(lines) > 4 else "" #to avoid index error for no names and bio's
    bio = " ".join(lines[5:]) if len(lines) > 5 else ""
    
    return {"username": username, "posts": posts, "followers": followers, "following": following,"name":name,"bio":bio}

# %%
all_chunks=[]
for chunk in chunks:
    parsed_chunk=parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
print(all_chunks)
# Out:
# [{'username': 'intaglobal', 'posts': 1946, 'followers': 6851, 'following': 262, 'name': 'INTA', 'bio': 'Nonprofit organization The association of ™ professionals. inta.campsite.bio'}, {'username': '_anujsinghal', 'posts': 1785, 'followers': 681000, 'following': 248000, 'name': 'Anuj Singhal', 'bio': 'Digital creator Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India Let’s talk about finance and life Contact: Singhalanuj1010@gmail.com hindi.cnbctv18.com/market-gurukul'}, {'username': 'code_flare', 'posts': 165, 'followers': 216, 'following': 10, 'name': 'The Journey Notebook | Travel | Food Blogger', 'bio': 'Blogger 📍 Exploring places & phases of life 🌍 . 🍵 From chai breaks to flight takes ✈️ . 💫 Travel | Food | Daily life 🌸 youtube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a'}, {'username': 'bangalore_tech_bro', 'posts': 402, 'followers': 12500, 'following': 890000, 'name': 'Rahul | HSR Hustler', 'bio': 'Entrepreneur 🚀 Building the next Unicorn in Fintech ☕ 3rd Wave Coffee addict 💻 Python | React | AI 📍 HSR Layout, BLR linktr.ee/rahulbuilds'}, {'username': 'silkboard_survivor', 'posts': 55, 'followers': 1200, 'following': 50, 'name': 'Priya D.', 'bio': 'Public Figure 🚦 Stuck in traffic since 2019 🌧️ Loving the Bangalore weather, hating the cabs 🐍 Data Scientist by day, meme maker by night 📍 ORR bit.ly/my-traffic-rants'}, {'username': 'startuphub_blr', 'posts': 2300, 'followers': 45000, 'following': 120000, 'name': 'Startup Hub Bangalore', 'bio': 'Media 🦄 News from the Silicon Valley of India 📢 Funding alerts, Hiring trends, and Drama 📩 DM for features startuphub.blr/newsletter'}, {'username': 'foodie_in_kora', 'posts': 890, 'followers': 5600, 'following': 400, 'name': 'Sneha | Bangalore Eats', 'bio': "Food & Drink Aagrah to Truffles 🍔 Exploring Koramangala's cafe culture ☕ DM for collabs https://www.google.com/search?q=zomato.com/users/sneha123"}, {'username': 'venture_vikram', 'posts': 120, 'followers': 30000, 'following': 500000, 'name': 'Vikram | Angel Investor', 'bio': 'Investor 💸 Helping founders go 0 to 1 Ex-Google, Ex-Amazon Investing in DeepTech & AI 📍 Indiranagar vikram.vc/pitch-deck'}, {'username': 'python_meetup_blr', 'posts': 60, 'followers': 3400, 'following': 10, 'name': 'PyBangalore Community', 'bio': 'Community 🐍 Weekly meetups for Pythonistas 📍 Cubbon Park | Sundays 4 PM Coding + Coffee + Community https://www.google.com/search?q=meetup.com/pybangalore'}, {'username': 'indiranagar_gossip', 'posts': 300, 'followers': 8900, 'following': 20, 'name': 'Indiranagar Spy', 'bio': 'Personal Blog Not just about 100ft Road 🤫 Spilling tea on the best brunches and worst landlords Bengaluru https://www.google.com/search?q=medium.com/%40indiranagarspy'}, {'username': 'ig_arbin07', 'posts': 50, 'followers': 33, 'following': 30, 'name': 'aarbinnn', 'bio': 'Gamer @dumb.arbin 🎮: Banana『juice (IGL🥷) Gamer never die, they just respawn🙂\u200d↔️'}, {'username': '7iiuliiu', 'posts': 1, 'followers': 44, 'following': 166, 'name': '︎𝐄︎ ♡︎.', 'bio': ''}, {'username': 'katiasales2220', 'posts': 107, 'followers': 219, 'following': 1401, 'name': 'Katia Sales', 'bio': 'Alfabetização e Reforço Escolar Ensino Fundamental I e II Preparação para Escola Militar Português e Matemática Cursando Psicopedagogia Estácio'}]

# %%
import json
s=json.dumps(all_chunks,indent=4)
print(s)
# this converts the data into dictionary format
# Out:
# [
#     {
#         "username": "intaglobal",
#         "posts": 1946,
#         "followers": 6851,
#         "following": 262,
#         "name": "INTA",
#         "bio": "Nonprofit organization The association of \u2122 professionals. inta.campsite.bio"
#     },
#     {
#         "username": "_anujsinghal",
#         "posts": 1785,
#         "followers": 681000,
#         "following": 248000,
#         "name": "Anuj Singhal",
#         "bio": "Digital creator Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India Let\u2019s talk about finance and life Contact: Singhalanuj1010@gmail.com hindi.cnbctv18.com/market-gurukul"
#     },
#     {
#         "username": "code_flare",
#         "posts": 165,
#         "followers": 216,
#         "following": 10,
#         "name": "The Journey Notebook | Travel | Food Blogger",
#         "bio": "Blogger \ud83d\udccd Exploring places & phases of life \ud83c\udf0d . \ud83c\udf75 From chai breaks to flight takes \u2708\ufe0f . \ud83d\udcab Travel | Food | Daily life \ud83c\udf38 youtube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a"
#     },
#     {
#         "username": "bangalore_tech_bro",
#         "posts": 402,
#         "followers": 12500,
#         "following": 890000,
#         "name": "Rahul | HSR Hustler",
#         "bio": "Entrepreneur \ud83d\ude80 Building the next Unicorn in Fintech \u2615 3rd Wave Coffee addict \ud83d\udcbb Python | React | AI \ud83d\udccd HSR Layout, BLR linktr.ee/rahulbuilds"
#     },
#     {
#         "username": "silkboard_survivor",
#         "posts": 55,
#         "followers": 1200,
#         "following": 50,
#         "name": "Priya D.",
#         "bio": "Public Figure \ud83d\udea6 Stuck in traffic since 2019 \ud83c\udf27\ufe0f Loving the Bangalore weather, hating the cabs \ud83d\udc0d Data Scientist by day, meme maker by night \ud83d\udccd ORR bit.ly/my-traffic-rants"
#     },
#     {
#         "username": "startuphub_blr",
#         "posts": 2300,
#         "followers": 45000,
#         "following": 120000,
#         "name": "Startup Hub Bangalore",
#         "bio": "Media \ud83e\udd84 News from the Silicon Valley of India \ud83d\udce2 Funding alerts, Hiring trends, and Drama \ud83d\udce9 DM for features startuphub.blr/newsletter"
#     },
#     {
#         "username": "foodie_in_kora",
#         "posts": 890,
#         "followers": 5600,
#         "following": 400,
#         "name": "Sneha | Bangalore Eats",
#         "bio": "Food & Drink Aagrah to Truffles \ud83c\udf54 Exploring Koramangala's cafe culture \u2615 DM for collabs https://www.google.com/search?q=zomato.com/users/sneha123"
#     },
#     {
#         "username": "venture_vikram",
#         "posts": 120,
#         "followers": 30000,
#         "following": 500000,
#         "name": "Vikram | Angel Investor",
#         "bio": "Investor \ud83d\udcb8 Helping founders go 0 to 1 Ex-Google, Ex-Amazon Investing in DeepTech & AI \ud83d\udccd Indiranagar vikram.vc/pitch-deck"
#     },
#     {
#         "username": "python_meetup_blr",
#         "posts": 60,
#         "followers": 3400,
#         "following": 10,
#         "name": "PyBangalore Community",
#         "bio": "Community \ud83d\udc0d Weekly meetups for Pythonistas \ud83d\udccd Cubbon Park | Sundays 4 PM Coding + Coffee + Community https://www.google.com/search?q=meetup.com/pybangalore"
#     },
#     {
#         "username": "indiranagar_gossip",
#         "posts": 300,
#         "followers": 8900,
#         "following": 20,
#         "name": "Indiranagar Spy",
#         "bio": "Personal Blog Not just about 100ft Road \ud83e\udd2b Spilling tea on the best brunches and worst landlords Bengaluru https://www.google.com/search?q=medium.com/%40indiranagarspy"
#     },
#     {
#         "username": "ig_arbin07",
#         "posts": 50,
#         "followers": 33,
#         "following": 30,
#         "name": "aarbinnn",
#         "bio": "Gamer @dumb.arbin \ud83c\udfae: Banana\u300ejuice (IGL\ud83e\udd77) Gamer never die, they just respawn\ud83d\ude42\u200d\u2194\ufe0f"
#     },
#     {
#         "username": "7iiuliiu",
#         "posts": 1,
#         "followers": 44,
#         "following": 166,
#         "name": "\ufe0e\ud835\udc04\ufe0e \u2661\ufe0e.",
#         "bio": ""
#     },
#     {
#         "username": "katiasales2220",
#         "posts": 107,
#         "followers": 219,
#         "following": 1401,
#         "name": "Katia Sales",
#         "bio": "Alfabetiza\u00e7\u00e3o e Refor\u00e7o Escolar Ensino Fundamental I e II Prepara\u00e7\u00e3o para Escola Militar Portugu\u00eas e Matem\u00e1tica Cursando Psicopedagogia Est\u00e1cio"
#     }
# ]

# %%
# 🎯 1. Who has maximum posts?
max_posts = max(all_chunks, key=lambda x: x["posts"])
print(max_posts)
# 🎯 2. Who has maximum followers?
max_followers = max(all_chunks, key=lambda x: x["followers"])
print(max_followers)
# 🎯 3. Who follows maximum people?
max_following = max(all_chunks, key=lambda x: x["following"])
print(max_following)
# 🎯 4. Total number of people
print(len(all_chunks))
# Out:
# {'username': 'startuphub_blr', 'posts': 2300, 'followers': 45000, 'following': 120000, 'name': 'Startup Hub Bangalore', 'bio': 'Media 🦄 News from the Silicon Valley of India 📢 Funding alerts, Hiring trends, and Drama 📩 DM for features startuphub.blr/newsletter'}
# {'username': '_anujsinghal', 'posts': 1785, 'followers': 681000, 'following': 248000, 'name': 'Anuj Singhal', 'bio': 'Digital creator Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India Let’s talk about finance and life Contact: Singhalanuj1010@gmail.com hindi.cnbctv18.com/market-gurukul'}
# {'username': 'bangalore_tech_bro', 'posts': 402, 'followers': 12500, 'following': 890000, 'name': 'Rahul | HSR Hustler', 'bio': 'Entrepreneur 🚀 Building the next Unicorn in Fintech ☕ 3rd Wave Coffee addict 💻 Python | React | AI 📍 HSR Layout, BLR linktr.ee/rahulbuilds'}
# 13
